# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
q = np.load('q.npy').reshape(3**4*2,6)

# %%
plt.imshow(q, aspect='auto')
plt.title('Q')
plt.ylabel('states')
plt.xlabel('action')
plt.colorbar()
plt.show()

# %%
np.genfromtxt('rewards.txt')
# Out:
# /Users/aaronschneider/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: genfromtxt: Empty input file: "rewards.txt"
#   """Entry point for launching an IPython kernel.
# array([], dtype=float64)
