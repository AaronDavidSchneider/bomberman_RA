# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
q = np.load('q.npy').reshape(8**3,6)

# %%
plt.imshow(q, aspect='auto')
plt.title('Q')
plt.ylabel('states')
plt.xlabel('action')
plt.show()
