# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

# %%
r=np.genfromtxt('rewards.txt')

# %%
window = 15

smoothed_rewards = savgol_filter(r, 51, 3)

#plt.plot(r)
plt.plot(smoothed_rewards)
plt.show()
