# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
q = np.load('q.npy').reshape(6**4*2,6)

# %%
plt.imshow(q, aspect='auto')
plt.title('Q')
plt.ylabel('states')
plt.xlabel('action')
plt.show()

# %%
a = np.array([1,2,3])
np.where(2==a)[0][0]
# Out:
# 1
