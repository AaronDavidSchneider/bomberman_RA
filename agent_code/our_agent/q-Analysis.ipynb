# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#q = np.load('q.npy').reshape(3**4*2,6)
w = np.load('weights.npy')

# %%
#plt.imshow(q, aspect='auto')
plt.plot(w)
plt.title('weights')
plt.ylabel('weight')
plt.xlabel('feature')
#plt.colorbar()
plt.show()

# %%
r=np.genfromtxt('rewards.txt')

# %%
window = 50
smoothed_rewards = [np.mean(r[i-window:i+1]) if i > window 
                    else np.mean(r[:i+1]) for i in range(len(r))]

#plt.plot(r)
plt.plot(smoothed_rewards)

# %%
def act_dot(f,w):
    return np.array([np.dot(f[i],w[i]) for i in range(6)])

# %%
f_list = []
q_list = []
w = np.array([np.random.rand(8)]*6)

for i in range(100):
    f = np.array([np.random.rand(8)]*6)
    q = act_dot(f,w)
    f_list.append(f)
    q_list.append(q)
    
    
f_list = np.array(f_list)
q_list = np.array(q_list)

# %%
np.dot(f_list,w).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-eb285a5ca213> in <module>
# ----> 1 np.dot(f_list,w).shape
#
# ValueError: shapes (100,6,8) and (6,8) not aligned: 8 (dim 2) != 6 (dim 0)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-f52337033a40> in <module>
# ----> 1 np.sum(act_dot(f_list.T,(q_list-act_dot(f_list,w)), axis=1))
#
# ValueError: operands could not be broadcast together with shapes (100,6) (6,6)
