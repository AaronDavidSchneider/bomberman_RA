# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import savgol_filter

# %%
r=np.genfromtxt('rewards.txt')

# %%
smoothed_rewards = savgol_filter(r, 51, 3) # window size 51, polynomial order 3

#plt.plot(r)
plt.plot(smoothed_rewards)
